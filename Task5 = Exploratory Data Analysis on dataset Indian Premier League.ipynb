# %% [markdown]
# # Author : MVPS AKHIL
# a Data Science and Business Analytics Intern at The Sparks Foundation
#
# # Task 5 : Exploratory Data Analysis on Sports (Indian Premier League)
#
#
# # Objective of Task 1 : To perform Exploratory Data Analysis on dataset : IPL.
#
#
# #GRIP AUGUST 2021 BATCH
#
# My Linkedin Profile : https://www.linkedin.com/in/mvps-akhil-b378b1178/
# My Github profile : https://github.com/dataisticakhil
# My youtube Profile : https://youtube.com/channel/UC0SoskTzWRUHgF80J7dWFOQ
# My Kaggle Profile : https://www.kaggle.com/dataisticakhil

# %% [markdown]
# # Loading the Packages

# %%
import pandas as np 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %%
matches = pd.read_csv('matches.csv')
matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %% [markdown]
# # Importing another dataset

# %%
deliveries =pd.read_csv('deliveries.csv')
deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
deliveries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %% [markdown]
# # Merging the Datasets

# %%
merge = pd.merge(deliveries,matches, left_on ='match_id', right_on ='id')
merge.head(5)
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  result  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...  normal
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...  normal
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...  normal
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...  normal
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...  normal
#
#    dl_applied               winner  win_by_runs  win_by_wickets  \
# ...

# %%
merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 179078 entries, 0 to 179077
# Data columns (total 39 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %%
matches.id.is_unique
# Out:
# True

# %%
matches.set_index('id', inplace = True)

# %% [markdown]
# # Match data statistics

# %%
matches.describe(include = 'all')
# Out:
#              season    city        date           team1  \
# count    756.000000     749         756             756
# unique          NaN      32         546              15
# top             NaN  Mumbai  2014-05-07  Mumbai Indians
# freq            NaN     101           2             101
# mean    2013.444444     NaN         NaN             NaN
# std        3.366895     NaN         NaN             NaN
# min     2008.000000     NaN         NaN             NaN
# 25%     2011.000000     NaN         NaN             NaN
# 50%     2013.000000     NaN         NaN             NaN
# 75%     2016.000000     NaN         NaN             NaN
# max     2019.000000     NaN         NaN             NaN
#
#                         team2     toss_winner toss_decision  result  \
# count                     756             756           756     756
# unique                     15              15             2       3
# top     Kolkata Knight Riders  Mumbai Indians         field  normal
# ...

# %% [markdown]
# # Pre processing the Data

# %%
matches.head()
# Out:
#     season       city        date                        team1  \
# id
# 1     2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 2     2017       Pune  2017-04-06               Mumbai Indians
# 3     2017     Rajkot  2017-04-07                Gujarat Lions
# 4     2017     Indore  2017-04-08       Rising Pune Supergiant
# 5     2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                           team2                  toss_winner toss_decision  \
# id
# 1   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 2        Rising Pune Supergiant       Rising Pune Supergiant         field
# 3         Kolkata Knight Riders        Kolkata Knight Riders         field
# 4               Kings XI Punjab              Kings XI Punjab         field
# 5              Delhi Daredevils  Royal Challengers Bangalore           bat
#
#     result  dl_applied                       winner  win_by_runs  \
# id
# ...

# %% [markdown]
# # Replacing the missing value in the city column

# %%
matches[matches.city.isnull()][['city','venue']]
# Out:
#     city                                venue
# id
# 462  NaN  Dubai International Cricket Stadium
# 463  NaN  Dubai International Cricket Stadium
# 467  NaN  Dubai International Cricket Stadium
# 469  NaN  Dubai International Cricket Stadium
# 470  NaN  Dubai International Cricket Stadium
# 475  NaN  Dubai International Cricket Stadium
# 477  NaN  Dubai International Cricket Stadium

# %% [markdown]
# # Replacing the missing values with : dubai

# %%
matches.city = matches.city.fillna('Dubai')

# %%
matches[(matches.umpire1.isnull()) | (matches.umpire2.isnull())]
# Out:
#        season           city        date                        team1  \
# id
# 5        2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
#
#                   team2                  toss_winner toss_decision  result  \
# id
# 5      Delhi Daredevils  Royal Challengers Bangalore           bat  normal
# 11413    Delhi Capitals               Delhi Capitals         field  normal
#
#        dl_applied                       winner  win_by_runs  win_by_wickets  \
# id
# 5               0  Royal Challengers Bangalore           15               0
# 11413           0               Delhi Capitals            0               2
#
#       player_of_match                  venue umpire1 umpire2 umpire3
# id
# 5           KM Jadhav  M Chinnaswamy Stadium     NaN     NaN     NaN
# 11413         RR Pant       ACA-VDCA Stadium     NaN     NaN     NaN

# %% [markdown]
# # As umpire 3 seems to be missing in most of the matches , we will drop the umpire3

# %%
matches = matches.drop('umpire3', axis = 1)

# %%
city_venue = matches.groupby(['city', 'venue']).count()['season']
city_venue_df = pd.DataFrame(city_venue)
city_venue_df
# Out:
#                                                                    season
# city           venue
# Abu Dhabi      Sheikh Zayed Stadium                                     7
# Ahmedabad      Sardar Patel Stadium, Motera                            12
# Bangalore      M Chinnaswamy Stadium                                   66
# Bengaluru      M Chinnaswamy Stadium                                    7
#                M. Chinnaswamy Stadium                                   7
# Bloemfontein   OUTsurance Oval                                          2
# Cape Town      Newlands                                                 7
# Centurion      SuperSport Park                                         12
# Chandigarh     Punjab Cricket Association IS Bindra Stadium, M...      11
#                Punjab Cricket Association Stadium, Mohali              35
# Chennai        M. A. Chidambaram Stadium                                8
# ...

# %% [markdown]
# # DATA VISUALIZATION

# %%
#venues-vs-cities 
v = pd.crosstab(matches['city'],matches['venue'])
v.replace(1, inplace=True)
# Out:
# venue
# ACA-VDCA Stadium                                        None
# Barabati Stadium                                        None
# Brabourne Stadium                                       None
# Buffalo Park                                            None
# De Beers Diamond Oval                                   None
# Dr DY Patil Sports Academy                              None
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     None
# Dubai International Cricket Stadium                     None
# Eden Gardens                                            None
# Feroz Shah Kotla                                        None
# Feroz Shah Kotla Ground                                 None
# Green Park                                              None
# Himachal Pradesh Cricket Association Stadium            None
# Holkar Cricket Stadium                                  None
# IS Bindra Stadium                                       None
# ...

# %%
#Adding a column to sum each column 
v['count'] = v.sum(axis = 'columns')

# %%
b = v['count']

# %%
#plotting
plt.figure(figsize = (20,7))
b.plot(kind = 'bar')
plt.title("Number of Stadiums", fontsize = 40, fontweight = 'bold')
plt.xlabel('City', size = 35)
plt.ylabel('Frequency', size = 35)
plt.xticks(size = 25)
plt.yticks(size = 25)
# Out:
# (array([  0.,  20.,  40.,  60.,  80., 100., 120.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# # Exploratory data analysis of nos. of matches played in each season

# %%
import seaborn as sn
plt.figure(figsize=(15,5))
plt.figure(figsize=(15,5))
sn.countplot('season', data = matches)
plt.title("Number of matches played in each season",fontsize = 20, fontweight = 'bold')
plt.xlabel("Season",size = 20)
plt.ylabel("Count",size = 20)
plt.xticks(size = 20)
plt.yticks(size = 20)
# Out:
# C:\Users\Akhil\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (array([ 0., 10., 20., 30., 40., 50., 60., 70., 80.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# # Venue with most number of matches held

# %%
matches.venue.value_counts().sort_values(ascending = True).tail(10).plot(kind = 'barh',figsize=(12,8), fontsize=15, color ='green')
plt.title("Venue with most number of matches held",fontsize=18,fontweight='bold')
plt.ylabel("Venue", size = 25)
plt.xlabel("Frequency", size = 25)
# Out:
# Text(0.5, 0, 'Frequency')

# %% [markdown]
# # Which team has dominated in IPL so far ?

# %%
#Creating dataframe with season and winner 
winning_teams = matches[['season','winner']]

#To get winners of each season 
winners_team = {}
for i in sorted(winning_teams.season.unique()):
    winners_team[i] = winning_teams[winning_teams.season == i]['winner'].tail(i).values[0]

winners_of_IPL = pd.Series(winners_team)
winners_of_IPL = pd.DataFrame(winners_of_IPL, columns=['team'])

# %%
winners_of_IPL['team'].value_counts().plot(kind = 'barh', figsize = (15,5), color = 'orange')
plt.title("Winners of IPL across 11 seasons", fontsize=18, fontweight="bold")
plt.xlabel("Frequency", size = 25)
plt.ylabel("Teams", size = 25)
plt.xticks(size = 15)
plt.yticks(size = 15)
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, 'Kolkata Knight Riders'),
#   Text(0, 1, 'Chennai Super Kings'),
#   Text(0, 2, 'Mumbai Indians'),
#   Text(0, 3, 'Sunrisers Hyderabad'),
#   Text(0, 4, 'Rising Pune Supergiants')])

# %% [markdown]
# # BAT FIRST OR BALL FIRST AFTER WINNING THE TOSS

# %%
matches['toss_decision'].value_counts().plot(kind='pie', fontsize=14, autopct='%3.1f%%',
                                             figsize=(10,7), shadow=True, startangle=135, legend=True, cmap='Oranges')
plt.ylabel('Decision on Toss')
plt.title('Decision by Captain after the toss')
# Out:
# Text(0.5, 1.0, 'Decision by Captain after the toss')

# %%
#toss decision affecting match results 
matches['toss_win_game_win'] = np.where((matches.toss_winner == matches.winner), 'Yes', 'No')
plt.figure(figsize = (15,5))
import seaborn as sn
sn.countplot('toss_win_game_win', data=matches, hue = 'toss_decision')
plt.title("How Toss Decision affects match result", fontsize=18,fontweight='bold')
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.xlabel("Winning Toss and winning match", fontsize = 25)
plt.ylabel("Frequency", fontsize = 25)
# Out:
# C:\Users\Akhil\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize = (25,10))
sn.countplot('toss_winner', data = matches, hue = 'toss_decision')
plt.title("Teams decision to bat first or second after winnning toss", size = 30, fontweight = 'bold')
plt.xticks(size = 10)
plt.yticks(size = 10)
plt.xlabel("Toss Winner", size =35)
plt.ylabel("Count", size = 35)
# Out:
# C:\Users\Akhil\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Count')

# %% [markdown]
# # Player performance which has led to teams victory

# %%
MoM= matches['player_of_match'].value_counts()
MoM.head(10).plot(kind = 'bar', figsize=(12,8), fontsize=15, color='red')
plt.title("Top 10 players with most number of man of the match awards",fontsize=18,fontweight='bold')
plt.ylabel("Frequency", size = 25)
plt.xlabel("Players", size = 25)
# Out:
# Text(0.5, 0, 'Players')

# %%
# Does fielding leads to win matches may vary across venues 
new_matches = matches[matches['result'] == 'normal'] #taking all those matches where result is normal and creating a new dataframe
new_matches['win_batting_first'] = np.where((new_matches.win_by_runs > 0), 'Yes', 'No')
new_matches.groupby('venue')['win_batting_first'].value_counts().unstack().plot(kind = 'barh', stacked =True, figsize=(15,15))
plt.title("How winning matches by fielding first varies across venues?", fontsize=18,fontweight='bold')
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.xlabel("Frequency", fontsize = 25)
plt.ylabel("Venue", fontsize = 25)
# Out:
# <ipython-input-35-ae99c8dd746c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_matches['win_batting_first'] = np.where((new_matches.win_by_runs > 0), 'Yes', 'No')
# Text(0, 0.5, 'Venue')

# %%
plt.figure(figsize = (15,5))
sn.countplot('season', data = new_matches, hue = 'win_batting_first')
plt.title("Is batting second advantageous across all years", fontsize=20,fontweight='bold')
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.xlabel("season", fontsize = 25)
plt.ylabel("Count", fontsize = 25)
# Out:
# C:\Users\Akhil\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Count')

# %% [markdown]
# # Has teams started to score high in recent years

# %%
merge.groupby('season')['batsman_runs'].sum().plot(kind = 'line', linewidth = 3, figsize=(13,5), color = 'black')
plt.title("Runs over the years", fontsize =25,fontweight = 'bold')
plt.xlabel("Season",size = 25)
plt.ylabel("Total Runs Scored", size = 25)
plt.xticks(size = 12)
plt.yticks(size = 12)
# Out:
# (array([15000., 16000., 17000., 18000., 19000., 20000., 21000., 22000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# # Runs scored and batting order

# %%
merge.groupby('batsman')['batsman_runs'].sum().sort_values(ascending = False).head(10).plot(kind = 'bar', color = 'green', figsize = (15,5))
plt.title("Top runs scorer in IPL", fontsize = 20, fontweight ='bold')
plt.xlabel("No. of Batsmen", size = 25)
plt.ylabel("Total runs scored", size = 25)
plt.xticks(size = 25)
plt.yticks(size = 25)
# Out:
# (array([   0., 1000., 2000., 3000., 4000., 5000., 6000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# # Who is the most consistent Batsman

# %%
consistent_batsman = merge[merge.batsman.isin(['SK Raina', 'V Kohli', 'RG Sharma','DA Warner', 'S Dhawan', 'CH Gayle', 'MS Dhoni', 'RV Uthappa', 'AB de Villiers', 'G Gambhir'])][['batsman','season','total_runs']]

consistent_batsman.groupby(['season','batsman'])['total_runs'].sum().unstack().plot(kind = 'box', figsize = (15,8))
plt.title("Most Consistent Batsman of the Season", fontsize = 20, fontweight = 'bold')
plt.xlabel("Batsman", size = 25)
plt.ylabel("Total runs scored in each season", size =25)
plt.xticks(size = 15)
plt.yticks(size = 15)
# Out:
# (array([-200.,    0.,  200.,  400.,  600.,  800., 1000., 1200.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# # Who is the best performing bowlers

# %%
merge.groupby('bowler')['player_dismissed'].count().sort_values(ascending = False).head(10).plot(kind = 'bar',color = 'green', figsize = (15,5))
plt.title("Top Wicket Taken in IPL", fontsize = 20, fontweight = 'bold')
plt.xlabel("Bowler", size = 25)
plt.ylabel("Total Wickets Taken", size = 25)
plt.xticks(size = 12)
plt.yticks(size = 12)
# Out:
# (array([  0.,  25.,  50.,  75., 100., 125., 150., 175., 200.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# # Bowler who bowled maximum time in IPL

# %%
balls = deliveries['bowler'].value_counts()[:10]
balls.plot(kind ='bar', title= "Bowlers who bowled maximum time", figsize=(12,6))
plt.xlabel("Bowler")
plt.ylabel("Balls")
plt.show()
balls = pd.DataFrame(balls)
balls.T
# Out:
#         Harbhajan Singh  A Mishra  PP Chawla  R Ashwin  SL Malinga  DJ Bravo  \
# bowler             3451      3172       3157      3016        2974      2711
#
#         B Kumar  P Kumar  UT Yadav  SP Narine
# bowler     2707     2637      2605       2600

# %%
#Bowlwers with maximum number of dot balls
dot_ball = deliveries[deliveries['total_runs']==0]
dot_ball = dot_ball['bowler'].value_counts()[:10]
dot_ball.plot(kind ='bar', figsize=(11,6), title = "Maximum Number of Dot balls")

plt.xlabel("Bowlers")
plt.ylabel("Balls")
plt.show()

dot_ball = pd.DataFrame(dot_ball)
dot_ball.T
# Out:
#         Harbhajan Singh  SL Malinga  B Kumar  A Mishra  PP Chawla  P Kumar  \
# bowler             1244        1144     1116      1108       1100     1075
#
#         R Ashwin  SP Narine  DW Steyn  UT Yadav
# bowler      1067       1038       996       942

# %% [markdown]
# # Extras

# %%
extra = deliveries[deliveries['extra_runs']!=0]['bowler'].value_counts()[:10]
extra.plot(kind = 'bar', figsize = (11,6), title = "Extra balls bowled by bowlers")

plt.xlabel("Bowler")
plt.ylabel("Balls")
plt.show()

extra = pd.DataFrame(extra)
extra.T
# Out:
#         SL Malinga  P Kumar  UT Yadav  DJ Bravo  B Kumar  SR Watson  I Sharma  \
# bowler         221      185       180       176      162        155       151
#
#         RP Singh  DW Steyn  R Ashwin
# bowler       145       139       133

# %% [markdown]
# # Most number of wickets taken

# %%
balls_bowled = pd.DataFrame(merge.groupby('bowler')['ball'].count())
wickets_taken = pd.DataFrame(merge[merge['dismissal_kind'] != 'no dismissal'].groupby('bowler')['dismissal_kind'].count())
seasons_played = pd.DataFrame(merge.groupby('bowler')['season'].nunique())
bowler_strike_rate = pd.DataFrame({'balls' :balls_bowled['ball'],'wickets' :wickets_taken['dismissal_kind'], 'season' :seasons_played['season']})
bowler_strike_rate.reset_index(inplace =True)

# %%
bowler_strike_rate['strike_rate'] = bowler_strike_rate['balls']/bowler_strike_rate['wickets']
def highlight_cols(s) :
    color = 'blue'
    return 'background-color: %s' % color

# %% [markdown]
# # Bowler's strike rate taken more than 50 wickets

# %%
best_bowling_strike_rate = bowler_strike_rate[bowler_strike_rate['wickets'] > 50].sort_values(by = 'strike_rate' , ascending =True)
best_bowling_strike_rate.head().style.applymap(highlight_cols, subset=pd.IndexSlice[:, ['bowler', 'wickets', 'strike_rate']])
# Out:
# <style  type="text/css" >
# #T_d8b228fb_f8df_11eb_9d0f_1cbfc0e41afarow0_col0,#T_d8b228fb_f8df_11eb_9d0f_1cbfc0e41afarow0_col2,#T_d8b228fb_f8df_11eb_9d0f_1cbfc0e41afarow0_col4,#T_d8b228fb_f8df_11eb_9d0f_1cbfc0e41afarow1_col0,#T_d8b228fb_f8df_11eb_9d0f_1cbfc0e41afarow1_col2,#T_d8b228fb_f8df_11eb_9d0f_1cbfc0e41afarow1_col4,#T_d8b228fb_f8df_11eb_9d0f_1cbfc0e41afarow2_col0,#T_d8b228fb_f8df_11eb_9d0f_1cbfc0e41afarow2_col2,#T_d8b228fb_f8df_11eb_9d0f_1cbfc0e41afarow2_col4,#T_d8b228fb_f8df_11eb_9d0f_1cbfc0e41afarow3_col0,#T_d8b228fb_f8df_11eb_9d0f_1cbfc0e41afarow3_col2,#T_d8b228fb_f8df_11eb_9d0f_1cbfc0e41afarow3_col4,#T_d8b228fb_f8df_11eb_9d0f_1cbfc0e41afarow4_col0,#T_d8b228fb_f8df_11eb_9d0f_1cbfc0e41afarow4_col2,#T_d8b228fb_f8df_11eb_9d0f_1cbfc0e41afarow4_col4{
#             background-color:  blue;
# ...

# %% [markdown]
# # Conclusion : I was able to carry out Exploratory Data Analysis on IPL dataset.
#
# # Thank you
